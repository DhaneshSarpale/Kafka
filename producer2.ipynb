# %%
import random
import time
from kafka import KafkaProducer

# Kafka broker address
bootstrap_servers = 'localhost:9092'

# Kafka topic to which the messages will be sent
topic1 = 'topic1'

# Create Kafka producer instance
producer = KafkaProducer(bootstrap_servers=bootstrap_servers)

def generate_random_number():
    return random.randint(1000, 9999)

try:
    while True:
        # Generate a random number
        random_number = generate_random_number()
        # Send the number as a string to the Kafka topic
        producer.send(topic1, value=str('B' + str(random_number)).encode('utf-8'))
        print(f"Sent: B{random_number}")
        time.sleep(1)
except KeyboardInterrupt:
    print("Producer stopped.")
finally:
    producer.close()
# Out:
# Sent: B8106
# Sent: B2940
# Sent: B8749
# Sent: B9496
# Sent: B6710
# Sent: B6257
# Sent: B6264
# Sent: B1399
# Sent: B8047
# Sent: B8688
# Sent: B6098
# Sent: B3862
# Sent: B9948
# Sent: B9165
# Sent: B5706
# Sent: B7549
# Sent: B9317
# Sent: B7511
# Sent: B7748
# Sent: B6678
# Sent: B3183
# Sent: B5606
# Sent: B9915
# Sent: B4453
# Sent: B6147
# Sent: B5465
# Sent: B8027
# Sent: B4858
# Sent: B5316
# Sent: B8838
# Sent: B2211
# Sent: B1334
# Sent: B4540
# Sent: B5021
# Sent: B1770
# Sent: B9023
# Sent: B7681
# Sent: B9533
# Sent: B4447
# Sent: B3254
# Sent: B8774
# Sent: B1139
# Sent: B2775
# Sent: B5873
# Sent: B6966
# Sent: B2602
# Sent: B7352
# Sent: B1454
# Sent: B6234
# Sent: B3121
# Sent: B5083
# Sent: B8785
# Sent: B3908
# Sent: B1682
# Sent: B7122
# Sent: B2470
# Sent: B3476
# Sent: B7069
# Sent: B5555
# Sent: B1329
# Sent: B7449
# Sent: B1007
# Sent: B7037
# Sent: B8547
# Sent: B2074
# Sent: B4851
# Sent: B6249
# Sent: B6204
# Sent: B6448
# Sent: B3712
# Sent: B3158
# Sent: B2042
# Sent: B7302
# Sent: B1096
# Sent: B7158
# Sent: B7711
# Sent: B6447
# Sent: B3631
# Sent: B9791
# Sent: B3058
# Sent: B9348
# Sent: B4107
# Sent: B4125
# Sent: B9428
# Sent: B6641
# Sent: B2875
# Sent: B9914
# Sent: B6671
# Sent: B8151
# Sent: B5395
# Sent: B6105
# Sent: B3661
# Sent: B7236
# Sent: B9322
# Sent: B3483
# Sent: B8929
# Sent: B9804
# Sent: B6025
# Sent: B3275
# Sent: B7229
# Sent: B7264
# Sent: B5398
# Sent: B4826
# Sent: B6521
# Sent: B9226
# Sent: B4796
# Sent: B6768
# Sent: B9299
# Sent: B3450
# Sent: B3294
# Sent: B2149
# Sent: B2330
# Sent: B2954
# Sent: B9600
# Sent: B4053
# Sent: B9954
# Sent: B2148
# Sent: B4619
# Sent: B3968
# Sent: B9752
# Sent: B8374
# Sent: B4615
# Sent: B1964
# Sent: B2803
# Sent: B7820
# Sent: B7592
# Sent: B6283
# Sent: B6382
# Sent: B1453
# Sent: B8615
# Sent: B7610
# Sent: B4811
# Sent: B2595
# Sent: B7515
# Producer stopped.
